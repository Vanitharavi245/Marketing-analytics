# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\mural\Downloads\3a67808bc59cf7347b9e23f575b4f1e7.csv")

# %%
df
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 1      2174        1954  Graduation         Single   46344        1         1
# 2      4141        1965  Graduation       Together   71613        0         0
# 3      6182        1984  Graduation       Together   26646        1         0
# 4      5324        1981         PhD        Married   58293        1         0
# ...     ...         ...         ...            ...     ...      ...       ...
# 2232  10870        1967  Graduation        Married   61223        0         1
# 2233   4001        1946         PhD       Together   64014        2         1
# 2234   7270        1981  Graduation       Divorced   56981        0         0
# 2235   8235        1956      Master       Together   69245        0         1
# 2236   9405        1954         PhD        Married   52869        1         1
#
# ...

# %%
df.isna().sum()
# Out:
# ID                0
# Year_Birth        0
# Education         0
# Marital_Status    0
# Income            0
# Kidhome           0
# Teenhome          0
# Dt_Customer       0
# Region            0
# Segment Code      0
# Recency           0
# Wines             0
# Fruits            0
# Meat              0
# Fish              0
# Sweet             0
# Gold              0
# Complain          0
# Response          0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                 int64
# Year_Birth         int64
# Education         object
# Marital_Status    object
# Income             int64
# Kidhome            int64
# Teenhome           int64
# Dt_Customer       object
# Region            object
# Segment Code      object
# Recency            int64
# Wines              int64
# Fruits             int64
# Meat               int64
# Fish               int64
# Sweet              int64
# Gold               int64
# Complain           int64
# Response           int64
# dtype: object

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Region', 'Segment Code', 'Recency', 'Wines',
#        'Fruits', 'Meat', 'Fish', 'Sweet', 'Gold', 'Complain', 'Response'],
#       dtype='object')

# %% [markdown]
# DATA WRANGLING

# %%
df.groupby('Region')[['ID']].count()
# Out:
#            ID
# Region
# Central   613
# East      380
# South    1002
# West      242

# %%
df.shape
# Out:
# (2237, 19)

# %%
df.groupby('Education')[['ID']].count()
# Out:
#               ID
# Education
# 2n Cycle     201
# Basic         54
# Graduation  1127
# Master       370
# PhD          485

# %%
df.groupby('Education')[['Recency']].mean()
# Out:
#               Recency
# Education
# 2n Cycle    48.293532
# Basic       48.444444
# Graduation  50.035492
# Master      47.586486
# PhD         48.509278

# %%
df.groupby('Marital_Status')[['Recency']].mean()
# Out:
#                   Recency
# Marital_Status
# Absurd          53.000000
# Alone           30.333333
# Divorced        49.272727
# Married         48.277778
# Single          49.561587
# Together        50.131261
# Widow           49.142857
# YOLO             3.000000

# %%
df.groupby('Segment Code')[['ID']].count()
# Out:
#                ID
# Segment Code
# BCF           102
# FHB           552
# GBQ           171
# GHR            69
# MLW           281
# TRX           878
# VKS           184

# %%
dfinc=df['Income']>50000
df[dfinc]
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 2      4141        1965  Graduation       Together   71613        0         0
# 4      5324        1981         PhD        Married   58293        1         0
# 5      7446        1967      Master       Together   62513        0         1
# 6       965        1971  Graduation       Divorced   55635        0         1
# ...     ...         ...         ...            ...     ...      ...       ...
# 2232  10870        1967  Graduation        Married   61223        0         1
# 2233   4001        1946         PhD       Together   64014        2         1
# 2234   7270        1981  Graduation       Divorced   56981        0         0
# 2235   8235        1956      Master       Together   69245        0         1
# 2236   9405        1954         PhD        Married   52869        1         1
#
# ...

# %%
drec=df['Recency']<40

# %%
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     864
# Together    579
# Single      479
# Divorced    231
# Widow        77
# Alone         3
# Absurd        2
# YOLO          2
# Name: count, dtype: int64

# %%
df.groupby('Marital_Status')[['Income']].mean()
# Out:
#                       Income
# Marital_Status
# Absurd          72365.500000
# Alone           43789.000000
# Divorced        52904.333333
# Married         51711.003472
# Single          50957.469729
# Together        53153.987910
# Widow           56397.376623
# YOLO            48432.000000

# %%
df.groupby('Marital_Status')[['Gold']].mean()
# Out:
#                       Gold
# Marital_Status
# Absurd          204.000000
# Alone            27.000000
# Divorced         46.380952
# Married          42.822917
# Single           43.816284
# Together         42.682211
# Widow            56.766234
# YOLO             42.000000

# %%
dage=df['Year_Birth'].sort_values()
dage.value_counts()
# Out:
# Year_Birth
# 1976    89
# 1971    87
# 1975    83
# 1972    79
# 1978    77
# 1970    77
# 1973    74
# 1965    74
# 1969    71
# 1974    69
# 1956    55
# 1958    53
# 1979    53
# 1952    52
# 1977    52
# 1959    51
# 1968    51
# 1954    50
# 1966    50
# 1955    49
# 1960    49
# 1982    45
# 1963    45
# 1967    44
# 1962    44
# 1957    43
# 1951    43
# 1964    42
# 1986    42
# 1983    42
# 1981    39
# 1980    39
# 1984    38
# 1961    36
# 1953    35
# 1985    32
# 1949    30
# 1989    30
# 1988    29
# 1950    29
# 1987    27
# 1948    21
# 1990    18
# 1947    16
# 1946    16
# 1991    15
# 1992    13
# 1945     8
# 1944     7
# 1943     7
# 1995     5
# 1993     5
# 1994     3
# 1996     2
# 1941     1
# 1940     1
# Name: count, dtype: int64

# %%
df["age"]= 2024-df['Year_Birth']
df
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 1      2174        1954  Graduation         Single   46344        1         1
# 2      4141        1965  Graduation       Together   71613        0         0
# 3      6182        1984  Graduation       Together   26646        1         0
# 4      5324        1981         PhD        Married   58293        1         0
# ...     ...         ...         ...            ...     ...      ...       ...
# 2232  10870        1967  Graduation        Married   61223        0         1
# 2233   4001        1946         PhD       Together   64014        2         1
# 2234   7270        1981  Graduation       Divorced   56981        0         0
# 2235   8235        1956      Master       Together   69245        0         1
# 2236   9405        1954         PhD        Married   52869        1         1
#
# ...

# %%
dage=df['age']<70
df70=df[dage]
df70
# Out:
#          ID  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0      5524        1957  Graduation         Single   58138        0         0
# 2      4141        1965  Graduation       Together   71613        0         0
# 3      6182        1984  Graduation       Together   26646        1         0
# 4      5324        1981         PhD        Married   58293        1         0
# 5      7446        1967      Master       Together   62513        0         1
# ...     ...         ...         ...            ...     ...      ...       ...
# 2230   9432        1977  Graduation       Together  666666        1         0
# 2231   8372        1974  Graduation        Married   34421        1         0
# 2232  10870        1967  Graduation        Married   61223        0         1
# 2234   7270        1981  Graduation       Divorced   56981        0         0
# 2235   8235        1956      Master       Together   69245        0         1
#
# ...

# %%
df70['Wines'].mean()
# Out:
# 288.7948984903696

# %%
df70['Gold'].mean()
# Out:
# 42.6730869338886

# %%
df70['Fruits'].mean()
# Out:
# 26.036439354502864

# %% [markdown]
# MODEL BUILDING

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Region', 'Segment Code', 'Recency', 'Wines',
#        'Fruits', 'Meat', 'Fish', 'Sweet', 'Gold', 'Complain', 'Response',
#        'age'],
#       dtype='object')

# %%
df1=df.drop(['ID','Year_Birth','Dt_Customer','Region'],axis=1)

# %%
df1
# Out:
#        Education Marital_Status  Income  Kidhome  Teenhome Segment Code  \
# 0     Graduation         Single   58138        0         0          TRX
# 1     Graduation         Single   46344        1         1          FHB
# 2     Graduation       Together   71613        0         0          MLW
# 3     Graduation       Together   26646        1         0          TRX
# 4            PhD        Married   58293        1         0          FHB
# ...          ...            ...     ...      ...       ...          ...
# 2232  Graduation        Married   61223        0         1          MLW
# 2233         PhD       Together   64014        2         1          FHB
# 2234  Graduation       Divorced   56981        0         0          TRX
# 2235      Master       Together   69245        0         1          GHR
# 2236         PhD        Married   52869        1         1          GBQ
#
#       Recency  Wines  Fruits  Meat  Fish  Sweet  Gold  Complain  Response  age
# ...
